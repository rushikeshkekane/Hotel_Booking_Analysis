# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshkekane/Hotel_Booking_Analysis/blob/master/Copy_of_Global_terrorism_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name** - Global Terrorism Dataset

# %% [markdown]
# **Project Type** - EDA
#
# **Contribution**- Team
#
# **Name** - Rushikesh kekane
#
# **Name** - Shantanu walunj

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Terrorism is an illegal and inhumane act, which aims to create fear in society. Terrorism is the greatest threat to human civilization and humanity. Terrorism has become a major global problem in the world as it can affect the lives and economy of any country. The terrorist attack has increased with the change in time. It is mostly caused due to the bad guru who could be a leader, dons, or any influential people who make them believe that they are superior in terms of religion, caste, country etc. But the fundamental elements are summarised as dissatisfaction, racism, linguistic differences, race, economic inequality and so on. And even money matters in most situations.
# The terrorism effects are vulnerable as it brings fear, death, wound, and insecurity to the country and can also change the government. But mostly innocent people are destroyed by terrorism as they face the destruction of lives and property. Terrorism can also get bring any country into an economic crisis and could degrade foreign exchange. It could bring high inflation to any county. The hottest zone of terrorism is the Middle East and North Africa. The most popular terrorist group are the Taliban, Al-quida, Boko Haram, ISIS, etc in this zone. Countries having the most problems with terrorism are Iraq, Pakistan, Afghanistan, Syria, Philippines, Somalia and El Salvador. Taliban and Al-quida have the highest number of casualties. It's confusing that most of the terrorists are from the Middle East and Muslims, but Muslims are mostly affected by terrorism. They are mostly attacked, killed and lost property by the attack of terrorism.
#
# Solution of Global Terrorism:-
#
# **1.** Developed countries need to bring refugees from the most affected countries. Because a city like Baghdad has more attacks than the whole world combined.
#
# **2.** Explosives and guns need to be controlled & Monitored.
#
# **3.** Explosive and gun detection systems need to be implemented
#
# **4.** Bunker should be made in public areas
#
# **5.** Most affected countries need to adopt modern technology
#
# **6.** Should make a strong network of the spy to monitor them and try to stop the future attack
#
# **7.** Implementation of more military personnel and security in the most affected cities
#
# **8.** Needs cooperation from the neighbouring and developed countries
#
# **9.** Need to conduct the bilateral Talk with the Terrorist Gangs
#
# In this Exploratory Data analysis, we have done lots of data selection and cleaning where we have removed unwanted noise from given data. We have tried different methods and figures for the storytelling of this analysis. We also intend to solve our objective and we have completed that through the EDA.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## **The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.**

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# # ***1. Know Your Data***

# %% [markdown]
# ## Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
from scipy import signal
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
import statistics
from statistics import mode
pd.set_option("display.max_columns", None)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
dataset = pd.read_csv("/content/Global Terrorism Data.csv",encoding='ISO-8859-1')

# %% [markdown]
# ## Dataset First View

# %%
# Dataset First Look
dataset.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %% [markdown]
# ## Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
dataset.shape
# Out:
# (181691, 135)

# %% [markdown]
# Since there are total of 135 columns in the data Renaming some columns which we are going to use for analysis

# %% [markdown]
# ## **Selecting & Re-naming required columns**

# %%
# Renaming the important columns
dataset = dataset.rename(columns = {'iyear':'Year',
                                    'imonth':'Month',
                                    'iday':'Day',
                                    'country_txt':'Country',
                                    'region_txt':'Region',
                                    'provstate':'State',
                                    'city':'City',
                                    'attacktype1_txt':'Attack_type',
                                    'targtype1_txt':'Target_type',
                                    'targsubtype1_txt':'Target_subtype',
                                    'gname':'Gang_name',
                                    'weaptype1_txt':'Weapon_type',
                                    'nkill':'Killed',
                                    'nwound':'Wounded'})

# %%
# Checking columns whether they are updated or not
dataset.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region                       Region    State  \
# 0  Dominican Republic       2  Central America & Caribbean      NaN
# 1              Mexico       1                North America  Federal
# 2         Philippines       5               Southeast Asia   Tarlac
# 3              Greece       8               Western Europe   Attica
# 4               Japan       4                    East Asia  Fukouka
#
#             City   latitude   longitude  specificity  vicinity location  \
# ...

# %%
# Selecting only important column which will be used for the analysis
terror_df = dataset[['Year','Month','Day','Country','Region','State','City',
                      'Attack_type','Target_type','Target_subtype','Gang_name','Weapon_type','Killed','Wounded']]

# %%
# Now checking the new dataset
terror_df.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
# ...

# %%
# checking its shape
terror_df.shape
# Out:
# (181691, 14)

# %% [markdown]
# There are 135 column in the dataset, But we required only 12 columns in the data so created the new dataset named *terror_df* and selected only 12 column in the new dataset.

# %% [markdown]
# ## **Dataset Information**

# %%
# Dataset Info
terror_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   State           181270 non-null  object
#  6   City            181257 non-null  object
#  7   Attack_type     181691 non-null  object
#  8   Target_type     181691 non-null  object
#  9   Target_subtype  171318 non-null  object
#  10  Gang_name       181691 non-null  object
#  11  Weapon_type     181691 non-null  object
#  12  Killed          171378 non-null  float64
#  13  Wounded         165380 non-null  float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 19.4+ MB

# %% [markdown]
# ## **Duplicate Values**

# %%
# Dataset Duplicate Value Count 181691
terror_df.duplicated().value_counts()
# Out:
# False    168635
# True      13056
# dtype: int64

# %% [markdown]
# We can clearly see that there are **16133** number of duplicate rows.Though it is the huge number we need to remove because Duplicate rows causes the error and has no use in the EDA

# %%
# Removing the duplicate rows
terror_df.drop_duplicates(inplace = True)

# %%
# Checking if dataset updated or not
terror_df.duplicated().value_counts()
# Out:
# False    168635
# dtype: int64

# %% [markdown]
# ## **Missing Values/Null Values**

# %%
# Missing Values/Null Values Count
print(terror_df.isnull().sum())
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# State               421
# City                424
# Attack_type           0
# Target_type           0
# Target_subtype     9188
# Gang_name             0
# Weapon_type           0
# Killed             9116
# Wounded           14854
# dtype: int64

# %%
# Visualizing the missing values
print(terror_df.isnull().sum())
plt.figure(figsize=(10,6))
sns.heatmap(terror_df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# State               421
# City                424
# Attack_type           0
# Target_type           0
# Target_subtype     9188
# Gang_name             0
# Weapon_type           0
# Killed             9116
# Wounded           14854
# dtype: int64
# <Axes: >

# %% [markdown]
# Heatmap shows it contains null values and these null values will be removed later..

# %% [markdown]
# ## **What did you know about your dataset?**

# %% [markdown]
# This is The Global Terrorism dataset from which is needed to analyse and explore the possible causes, trends and patterns in the act of terrorism. In this dataset it has 181691 rows and 135 columns But we selected the important columns and all rows to perform the Exploratory Data Analysis. There are 16133 duplicate rows in the dataset which has been removed from the dataset. Its three columns has null values.They are :
#
#
# **1.** State
#
# **2.** City
#
# **3.** Target_subtype

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
terror_df.columns.tolist()
# Out:
# ['Year',
#  'Month',
#  'Day',
#  'Country',
#  'Region',
#  'State',
#  'City',
#  'Attack_type',
#  'Target_type',
#  'Target_subtype',
#  'Gang_name',
#  'Weapon_type',
#  'Killed',
#  'Wounded']

# %% [markdown]
# ## **Variables Description**

# %%
# Dataset Describe
terror_df.describe(include = 'all')
# Out:
#                  Year          Month            Day Country  \
# count   168635.000000  168635.000000  168635.000000  168635
# unique            NaN            NaN            NaN     205
# top               NaN            NaN            NaN    Iraq
# freq              NaN            NaN            NaN   22959
# mean      2003.081893       6.469464      15.526516     NaN
# std         13.161817       3.390868       8.815249     NaN
# min       1970.000000       0.000000       0.000000     NaN
# 25%       1991.000000       4.000000       8.000000     NaN
# 50%       2009.000000       6.000000      15.000000     NaN
# 75%       2014.000000       9.000000      23.000000     NaN
# max       2017.000000      12.000000      31.000000     NaN
#
#                             Region    State     City        Attack_type  \
# count                       168635   168214   168211             168635
# unique                          12     2855    36674                  9
# ...

# %% [markdown]
# ## **Check Unique Values for each variable.**

# %%
# Check Unique Values for each variable.
column_list = terror_df.columns.tolist()
for i in column_list:
  print("\033[1m" + i + "\033[0m")
  print("Unique values are: \n ",terror_df[i].unique().tolist())
  print("No. of unique values : ", terror_df[i].nunique(),".\n")
# Out:
# Year
# Unique values are:
#   [1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991, 1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
# No. of unique values :  47 .
#
# Month
# Unique values are:
#   [7, 0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 12]
# No. of unique values :  13 .
#
# Day
# Unique values are:
#   [2, 0, 1, 3, 6, 8, 9, 10, 11, 12, 13, 14, 15, 19, 20, 21, 22, 25, 26, 27, 28, 30, 31, 4, 7, 16, 17, 18, 23, 24, 5, 29]
# No. of unique values :  32 .
#
# Country
# Unique values are:
# ...

# %% [markdown]
# Its value has lots of problem which needed to be fixed in the Data Wrangling part

# %% [markdown]
# ## **3. Data Wrangling**

# %% [markdown]
# Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# creating the copy of the current datast
df = terror_df.copy()

# %% [markdown]
# Handling null values

# %%
# Handling the null values and the unknown values

print(df.isnull().sum())
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# State               421
# City                424
# Attack_type           0
# Target_type           0
# Target_subtype     9188
# Gang_name             0
# Weapon_type           0
# Killed             9116
# Wounded           14854
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10,6))
sns.heatmap(
    df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# <Axes: >

# %% [markdown]
# Heatmap shows null values and these are clearly the sensetive values so droping wont be solution. So null values are handled separetly.

# %% [markdown]
# **1.** State
#
# **2.** City
#
# **3.** Target_subtype
#
# **4.** Killed

# %%
# filling null values of city and State as Unknown
df['City'].fillna('Unknown',inplace = True)
df['State'].fillna('Unknown',inplace = True)

# %%
 df['Killed'].fillna(value = int(df['Killed'].mean()),inplace = True)

# %%
# filling null values of Target_subtype as Others
df['Target_subtype'].fillna('Others',inplace = True)

# %%
# filling null vlaues of the  Wounded with the mean
df['Wounded'].fillna(value = int(df['Wounded'].mean()),inplace = True)

# %%
# Visualizing the missing values if any thorugh Heatmap
sns.heatmap(df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# <Axes: >

# %% [markdown]
# The above Heatmap show absence of null values.

# %% [markdown]
# **Naming properly**

# %%
# Function to check column properly
def column_check(column):
  print(column)
  print("Unique values are: \n ", df[column].unique().tolist())
  print("No. of unique values : ", df[column].nunique(),".\n")

# %%
column_check('Year')
# Out:
# Year
# Unique values are:
#   [1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991, 1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
# No. of unique values :  47 .

# %%
column_check('Month')
# Out:
# Month
# Unique values are:
#   [7, 0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 12]
# No. of unique values :  13 .

# %%
#checking the total values with month equals to 0
print(len(df[df['Month'] == 0]))
# Out:
# 19

# %%
# Replacing the 0 with mode value in the month because it may have some significance in that month
df.loc[df['Month'] == 0,'Month']= mode(df['Month'])

# %%
#checking whether it is updated or not
column_check('Month')
# Out:
# Month
# Unique values are:
#   [7, 5, 1, 2, 3, 4, 6, 8, 9, 10, 11, 12]
# No. of unique values :  12 .

# %%
# Checking the unique values of the column Day
column_check("Day")
# Out:
# Day
# Unique values are:
#   [2, 0, 1, 3, 6, 8, 9, 10, 11, 12, 13, 14, 15, 19, 20, 21, 22, 25, 26, 27, 28, 30, 31, 4, 7, 16, 17, 18, 23, 24, 5, 29]
# No. of unique values :  32 .

# %%
# Checking the length of day equals to the zero
print(len(df[df['Day'] == 0]))
# Out:
# 793

# %% [markdown]
# We do not have **O** in number in the day, So we will be removing that **Day O** with mode

# %%
# Replacing 0 value with most frequent number
df.loc[df['Day']==0,'Day'] = mode(df['Day'])

# %%
# Checking if its updated or not
column_check("Day")
# Out:
# Day
# Unique values are:
#   [2, 15, 1, 3, 6, 8, 9, 10, 11, 12, 13, 14, 19, 20, 21, 22, 25, 26, 27, 28, 30, 31, 4, 7, 16, 17, 18, 23, 24, 5, 29]
# No. of unique values :  31 .

# %%
# Checking the unique values of the column Country
column_check("Country")
# Out:
# Country
# Unique values are:
# ...

# %% [markdown]
# We can see there are many countries which have been partitioned and captured by others like the Soviet Union, East Germany & West Germany, the west bank and Gaza Strip and so on. So we will not do anything to these but There is no country as the International so we will take a look at this.

# %%
#checking the country International
df[df['Country']=='International']
# Out:
#        Year  Month  Day        Country                      Region  \
# 74658  2002     10    6  International  Middle East & North Africa
#
#               State          City        Attack_type Target_type  \
# 74658  Gulf of Aden  Gulf of Aden  Bombing/Explosion    Maritime
#
#       Target_subtype Gang_name Weapon_type  Killed  Wounded
# 74658     Oil Tanker  Al-Qaida  Explosives     1.0     12.0

# %% [markdown]
# We rename International to Gulf of Aden.

# %%
# Renaming International to the Gulf of Aden
df.loc[df['Country']=='International','Country'] = 'Gulf of Aden'

# %%
# Checking if its updated or not
df[df['Country']=='Gulf of Aden']
# Out:
#        Year  Month  Day       Country                      Region  \
# 74658  2002     10    6  Gulf of Aden  Middle East & North Africa
#
#               State          City        Attack_type Target_type  \
# 74658  Gulf of Aden  Gulf of Aden  Bombing/Explosion    Maritime
#
#       Target_subtype Gang_name Weapon_type  Killed  Wounded
# 74658     Oil Tanker  Al-Qaida  Explosives     1.0     12.0

# %%
column_check('Region')
# Out:
# Region
# Unique values are:
#   ['Central America & Caribbean', 'North America', 'Southeast Asia', 'Western Europe', 'East Asia', 'South America', 'Eastern Europe', 'Sub-Saharan Africa', 'Middle East & North Africa', 'Australasia & Oceania', 'South Asia', 'Central Asia']
# No. of unique values :  12 .

# %%
# Checking the unique values of State
column_check('State')
# Out:
# State
# Unique values are:
# ...

# %%
# Checking values of the city
column_check('City')
# Out:
# City
# Unique values are:
# ...

# %%
column_check('Attack_type')
# Out:
# Attack_type
# Unique values are:
#   ['Assassination', 'Hostage Taking (Kidnapping)', 'Bombing/Explosion', 'Facility/Infrastructure Attack', 'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault', 'Hostage Taking (Barricade Incident)']
# No. of unique values :  9 .

# %% [markdown]
# Lets use the simple and small name

# %%
# Changing the Hostage Taking(Kidnapping) to the Kidnapping and 'Hostage Taking (Barricade Incident)' to the Barricade Incident
df.loc[df['Attack_type'] == 'Hostage Taking (Kidnapping)','Attack_type'] = 'Kidnapping'
df.loc[df['Attack_type'] == 'Hostage Taking (Barricade Incident)','Attack_type'] = 'Barricade Incident'

# %%
# checking if its updated or not
df[df['Attack_type'] == 'Barricade Incident']
# Out:
#         Year  Month  Day        Country                      Region  \
# 336     1970      6    9         Jordan  Middle East & North Africa
# 469     1970      8   21        Uruguay               South America
# 941     1971      7   21  United States               North America
# 1211    1972      3   16  United States               North America
# 1570    1972      9   29  United States               North America
# ...      ...    ...  ...            ...                         ...
# 180703  2017     11   23        Nigeria          Sub-Saharan Africa
# 181239  2017     12   11          India                  South Asia
# 181383  2017     12   18      Venezuela               South America
# 181615  2017     12   28          India                  South Asia
# 181660  2017     12   30        Ukraine              Eastern Europe
#
#              State                      City         Attack_type  \
# 336          Amman                     Amman  Barricade Incident
# ...

# %%
# Viewing the Kidnapping type
df[df['Attack_type'] == 'Kidnapping']
# Out:
#         Year  Month  Day      Country                       Region  \
# 1       1970      5   15       Mexico                North America
# 27      1970      1   22    Venezuela                South America
# 103     1970      3    3        Spain               Western Europe
# 112     1970      3    6    Guatemala  Central America & Caribbean
# 123     1970      3   11       Brazil                South America
# ...      ...    ...  ...          ...                          ...
# 181616  2017     12   28        Yemen   Middle East & North Africa
# 181620  2017     12   28  Afghanistan                   South Asia
# 181630  2017     12   28  Philippines               Southeast Asia
# 181636  2017     12   29  Afghanistan                   South Asia
# 181684  2017     12   31        India                   South Asia
#
#                  State                     City Attack_type  \
# 1              Federal              Mexico city  Kidnapping
# ...

# %%
# Checking the unique values of the Target_type
column_check('Target_type')
# Out:
# Target_type
# Unique values are:
#   ['Private Citizens & Property', 'Government (Diplomatic)', 'Journalists & Media', 'Police', 'Utilities', 'Military', 'Government (General)', 'Airports & Aircraft', 'Business', 'Educational Institution', 'Violent Political Party', 'Religious Figures/Institutions', 'Unknown', 'Transportation', 'Tourists', 'NGO', 'Telecommunication', 'Food or Water Supply', 'Terrorists/Non-State Militia', 'Other', 'Maritime', 'Abortion Related']
# No. of unique values :  22 .

# %%
#checking the Target_subtype values
column_check('Target_subtype')
# Out:
# Target_subtype
# Unique values are:
# ...

# %%
column_check('Gang_name')
# Out:
# Gang_name
# Unique values are:
# ...

# %%
column_check('Weapon_type')
# Out:
# Weapon_type
# Unique values are:
#   ['Unknown', 'Explosives', 'Incendiary', 'Firearms', 'Chemical', 'Melee', 'Sabotage Equipment', 'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)', 'Fake Weapons', 'Radiological', 'Other', 'Biological']
# No. of unique values :  12 .

# %% [markdown]
# Here in Weapon_type one of the unique values is : **Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)'** it is too lengthy so this value is changed to Vehicle and also changing the Unknown to the Other

# %%
# Changing big name to Vehicle
df.replace( {"Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)": "Vehicle"},inplace = True)

# %%
# Changing the 'Unknown' to the 'Other
df.loc[df['Weapon_type'] == 'Unknown','Weapon_type'] = 'Other'

# %%
# Checking if its updated or not
df['Weapon_type'].unique()
# Out:
# array(['Other', 'Explosives', 'Incendiary', 'Firearms', 'Chemical',
#        'Melee', 'Sabotage Equipment', 'Vehicle', 'Fake Weapons',
#        'Radiological', 'Biological'], dtype=object)

# %%
# Check again
df.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean  Unknown
# 1  1970      5   15              Mexico                North America  Federal
# 2  1970      1   15         Philippines               Southeast Asia   Tarlac
# 3  1970      1   15              Greece               Western Europe   Attica
# 4  1970      1   15               Japan                    East Asia  Fukouka
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city                      Kidnapping      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
# ...

# %% [markdown]
# **Exploring the Hospot of Terrorism**

# %%
# Top 10 Country with most number of Terrorism
df['Country'].value_counts()[:10]
# Out:
# Iraq              22959
# Pakistan          13551
# Afghanistan       12400
# India             11443
# Colombia           7349
# Philippines        6715
# United Kingdom     4868
# Peru               4843
# El Salvador        4181
# Somalia            4059
# Name: Country, dtype: int64

# %%
# Bottom 10 Country with less number of Terrorism
df['Country'].value_counts().tail(10)
# Out:
# New Hebrides           1
# South Vietnam          1
# North Korea            1
# St. Lucia              1
# Andorra                1
# Gulf of Aden           1
# Vatican City           1
# Wallis and Futuna      1
# Falkland Islands       1
# Antigua and Barbuda    1
# Name: Country, dtype: int64

# %%
# Getting the top of every things
print("Country with the most attacks:",df['Country'].value_counts().idxmax())
print("Total Number of people died due to the Terrerist Attack are:",df['Killed'].sum())
print("Total Numebr of people wounded due to the Terrorist attaked are:",df['Wounded'].sum())
print("City with the most attacks:",df['City'].value_counts().index[1])
print("Region with the most attacks:",df['Region'].value_counts().idxmax())
print("Year with the most attacks:",df['Year'].value_counts().idxmax())
print("Month with the most attacks:",df['Month'].value_counts().idxmax())
print("Group with the most attacks:",df['Gang_name'].value_counts().index[1])
print("Total number of Terrorist groups: ",len(df['Gang_name'].value_counts()))

print("Most Attack Types:",df['Attack_type'].value_counts().idxmax())
# Out:
# Country with the most attacks: Iraq
# Total Number of people died due to the Terrerist Attack are: 424013.0
# Total Numebr of people wounded due to the Terrorist attaked are: 561104.0
# City with the most attacks: Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Total number of Terrorist groups:  3537
# Most Attack Types: Bombing/Explosion

# %%
#print("Group with the most attacks:",)
len(df['Gang_name'].value_counts())
# Out:
# 3537

# %%
# Defining Function to get details of terrorist activities of that any country
def Details_country(X):
      country = df[df['Country'] == X].reset_index(drop = True)
      print('Total Number of people has been killed due to the terrorism is :',country['Killed'].sum())
      print('Total Nummber of Wounded are : ',country['Wounded'].sum())
       # Top most affected State is
      print("\nThe most affected State is ", country['State'].value_counts().idxmax())
      # Top most affected city of Iran
      print("\nThe most affected City is", country['City'].value_counts().idxmax())
      # Higest Attack type
      print("\nThe higest type of attack is is ", country['Attack_type'].value_counts().idxmax())
      print('\nMost Target is ',country['Target_type'].value_counts().idxmax())
      print('\nMost Exactly Target ',country['Target_subtype'].value_counts().idxmax())
      print("\nGangs Responsible for Most terrerism is ",country['Gang_name'].value_counts().idxmax())
      print("\nMost used weapon is",country['Weapon_type'].value_counts().idxmax())

# %%
#taking the list of country to explore
list_country = ['Iraq','Pakistan','Afghanistan','India','Colombia','Philippines','United Kingdom','El Salvador','Somalia']

# %%
for country in list_country:
  print("Details of Terrorism  \t" + country)
  print('**********************************************')
  Details_country(country)
  print("\n-------------------------------------------------------------------")
# Out:
# Details of Terrorism  	Iraq
# **********************************************
# Total Number of people has been killed due to the terrorism is : 78918.0
# Total Nummber of Wounded are :  136536.0
#
# The most affected State is  Baghdad
#
# The most affected City is Baghdad
#
# The higest type of attack is is  Bombing/Explosion
#
# Most Target is  Private Citizens & Property
#
# Most Exactly Target  Unnamed Civilian/Unspecified
#
# Gangs Responsible for Most terrerism is  Unknown
#
# Most used weapon is Explosives
#
# -------------------------------------------------------------------
# Details of Terrorism  	Pakistan
# **********************************************
# Total Number of people has been killed due to the terrorism is : 23903.0
# Total Nummber of Wounded are :  42963.0
#
# The most affected State is  Balochistan
#
# The most affected City is Karachi
#
# The higest type of attack is is  Bombing/Explosion
#
# Most Target is  Private Citizens & Property
#
# ...

# %%
# Get into the details of the India
Details_country('India')
# Out:
# Total Number of people has been killed due to the terrorism is : 19547.0
# Total Nummber of Wounded are :  29578.0
#
# The most affected State is  Jammu and Kashmir
#
# The most affected City is Srinagar
#
# The higest type of attack is is  Bombing/Explosion
#
# Most Target is  Private Citizens & Property
#
# Most Exactly Target  Police Security Forces/Officers
#
# Gangs Responsible for Most terrerism is  Unknown
#
# Most used weapon is Explosives

# %%
# Create Data set for the India
India = df[df['Country'] == 'India'].reset_index(drop = True)

# %%
# Top Indian state with number of the terrorism activity
India['State'].value_counts()[:5]
# Out:
# Jammu and Kashmir    2333
# Assam                1080
# Manipur              1066
# Chhattisgarh          969
# Punjab                862
# Name: State, dtype: int64

# %% [markdown]
# Most affected area is Jammu and Kashmir.

# %%
# Top Indian city with number of the terrorism activity
India['City'].value_counts()[:5]
# Out:
# Srinagar     594
# Unknown      498
# Imphal       407
# New Delhi    149
# Amritsar     137
# Name: City, dtype: int64

# %% [markdown]
# Jammu and Kashmir city has the most number of terrorist activity

# %%
# Top 5 Attack type
India['Attack_type'].value_counts()[:5]
# Out:
# Bombing/Explosion                 4584
# Armed Assault                     3119
# Assassination                     1191
# Kidnapping                        1167
# Facility/Infrastructure Attack     869
# Name: Attack_type, dtype: int64

# %% [markdown]
# Most terrorist attacks by Bombing/Explosion or by the Armed Assault

# %%
# India top 5 Target_type
India['Target_type'].value_counts()[:5]
# Out:
# Private Citizens & Property    2982
# Police                         2233
# Government (General)           1655
# Business                       1068
# Military                        911
# Name: Target_type, dtype: int64

# %% [markdown]
# The most affected Target is Private Citizens & property and after that police, and Government's General are targeted

# %%
# Top 5 Gangs
India['Gang_name'].value_counts()[:5]
# Out:
# Unknown                                           4142
# Communist Party of India - Maoist (CPI-Maoist)    1829
# Maoists                                           1360
# Sikh Extremists                                    659
# United Liberation Front of Assam (ULFA)            344
# Name: Gang_name, dtype: int64

# %% [markdown]
# Most attacks are done by Unknown terrorist groups.

# %% [markdown]
# ## **What all manipulations have you done and insights you found?**

# %% [markdown]
# **Manupulation :**
#
# Null values present in the state, City has been imputed by the Unknown values and Target_subtype by Other and Killed and wounded has been filled with the mean of the value.
#
# The 0 present in the field of the Day and Month are replaced with mode
#
# A country with the value
#
# International has been replaced with the Gulf of Aden
#
# Attack_type Hostage Taking (Kidnapping) and Hostage Taking (Barricade Incident) has been replaced with the Kidnapping and Barricade Incident respectively
#
# 'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs' has been changed to 'Vehicle' in Weapon_type
#
# **Insights :**
#
# It's shocking to see that most of the country's main Target is **Private citizens & property** where they have attacked **Normal Unarmed Civilian** they are attacked with Bombing or Explosion and in other country, military personnel and police officer has been attacked.
#
#
# Iraq has been attacked most.
#
# Total Number of people who died due to the Terrorist Attack are: 424013.0
#
# Total Number of people wounded due to the Terrorist attacks are: 561104.0
#
# City with the most attacks: Baghdad
#
# Region with the most attacks: Middle East & North Africa
#
# Year with the most attacks: 2014
#
# Month with the most attacks: 5
#
# Group with the most attacks: Taliban
#
# Most Attack Types: Bombing/Explosion
#
# Total number of Terrorist groups: 3537
#
# In India most venerable state is Jammu & Kashmir

# %% [markdown]
# # ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## **Chart - 1 - Word Cloud i.e City (Univariate)**

# %%
# Chart - 1 visualization code
# Selecting the city except the Unknown
cities = df.loc[df['City'] !='Unknown','City']
plt.subplots(figsize=(10,8))
wordcloud = WordCloud(background_color = 'white',
                     width = 512,
                     height = 384).generate('  '.join(cities))
plt.axis('off')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?
#
# A word cloud is a visual representation of information or data. It shows the popularity of words or phrases by making the most frequently used words appear larger or bolder compared with the other words around them.We choose these word clouds because these are the visual representation of words that give greater prominence to words that appear more frequently. When using a word cloud generator, the words that are added most frequently by audience members will increase in size dynamically. So cities connected with terrorism will be occurring more and have bigger and bold text. 36674 cities have been attacked. So to get all the cities in one frame according to the frequency of the attack this chart is picked
#
# 2. What is/are the insight(s) found from the chart?
#
# From this above chart we can see the cities which have more terrorist attacks. The cities with the most attacks are Baghdad,Salvador,Karachi, Mogadishu, Peshawar, Istanbul, Lima, Kabul and so on.
#
# 3. Will the gained insights help creating a positive business impact?
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# From this gained insights, it can help the government and International agencies to give priority to security Enhancement, should provide more security personnel & military and can put more restrictions on the use of arms and ammunition in cities with first sight of Cities name from the clouds of words.

# %% [markdown]
# ## **Chart - 2 The rise of terrorism.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 10))
sns.countplot(x="Year", data=df)
plt.title('Terrorist Attack Each Year')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# The count plot represents the count of the categorical data with rectangular bars with heights or lengths proportional to the frequency of each variable. Here we have represented the number of terrorist attacks each year and the height of the bar is proportional to the number of attacks every year.
#
# **2. What is/are the insight(s) found from the chart?**
#
# It can be seen from the bar graph, The number of attacks are increasing as the year elapsed but in 1998 the number of attacks took a significant dip significantly but again increases as the year passes. 2014 has the most number of attacks. The '70s have fewer attacks than other decades.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Government and International organizations should take terrorism more seriously. They should focus more on security and increasing spy networks and should do something so they can reduce this terrorism and should ask the question WHY TERRORISM KEEPS ON INCREASING EVEN AFTER ADAPTING modern technology and facilities? Because this is a very serious matter as terrorism keeps on increasing even after so much effort. I think Government and different organizations should take different approaches to reduce terrorism.

# %% [markdown]
# ## **Chart - 3 People Killed/Wounded Every Year**

# %%
# Chart - 3 Number of People killed or wounded every Year
Casualty = df.groupby("Year", as_index = False).agg({'Killed':'sum',
                                                              'Wounded':'sum'})

# %%
# line plot with multiple lines in the graph
plt.figure(figsize = (12,10))
sns.lineplot(data = Casualty, x = 'Year', y = 'Killed',label = "Killed")
sns.lineplot(data = Casualty, x = 'Year', y = 'Wounded',label = "Wounded")
plt.xticks(np.arange(2000,2017,1))

plt.title('Casualty Per Year')
plt.xlabel(" Year")
plt.ylabel("Number of Casualty ")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# A multiple line graph is a line graph that shows more than one variable for comparison trends between two attributes of quality and a line graph is very much effective in the time series. So we have chosen this multiple graphs, which will show the number of wounded and death per year in a single graph.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Line charts represent both Numbers of wounded and killed per year as both of them are going simultaneously. In the '70s terrorist attacks were minimum as time elapsed the attacks increased significantly. In 2014 it shows the highest number of people killed and in 2015 has the highest number of wounded due to terrorist attacks. Since 2014 terrorism has increased significantly and after 2015 terrorism has decreased.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# It shows the total number of killed or wounded per year. The attacks could be reduced at some point like in 1998 and 2015 but the remaining attacks keep on increasing and the Government and other organizations should take necessary action to prevent terrorism.

# %% [markdown]
# ## **Chart - 4 Year vs Region**

# %%
# Chart -
pd.crosstab(df['Year'], df['Region']).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# An area chart is a graph that combines a line chart and a bar chart to show changes in quantities over time. It’s similar to a line graph in that data points are plotted and connected by line segments. However, the area below the line is coloured in or shaded. Then, other values are plotted below the lines and shaded in a different color, resulting in a chart with layers.
#
# **2. What is/are the insight(s) found from the chart?**
#
# In the '70s North America and Central America & Caribbean region seems to have more terrorist attacks.
#
# From 1990 Middle East and North Africa started getting more involved in terrorism and went to peak from 2010 to 2017.
#
# There is a rapid increase in terrorism from twenty century
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# The area covered by the region is the most affected region and suggests any government make space with these countries traveling into your country. Because there is a high chance that they can be linked with terrorists. In contrast, the resourceful country needs to build a refugee camp to support the victims of terrorism.

# %% [markdown]
# ## **Chart - 5 Top 10 countries and Region affected by the terrorist attack.**

# %%
fig,axes = plt.subplots(figsize=(16,11),nrows=1,ncols=2)
sns.barplot(x = df['Country'].value_counts()[:20].values, y = df['Country'].value_counts()[:20].index,
            ax=axes[0],palette = 'magma');
axes[0].set_title('Terrorist Attacks per Country')
sns.barplot(x=df['Region'].value_counts().values,y=df['Region'].value_counts().index,
            ax=axes[1])
axes[1].set_title('Terrorist Attacks per Region')
fig.tight_layout()
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# It represents the graphical information of the categorical value. and its height is proportional to the values that they represent so we need the bar graph to compare the different countries and regions. Here a double bar chart has been plotted so that multiple studies can be done.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Bar char shows the top ten countries affected by the terrorism. Most affected country is Iraq. Most affected region is Middle East and North Africa
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# It shows the path to build security parameters and focuses more on the specific country/Region from where it can be stopped. As it tells us to take measures and priority of reform in the security system and assign more armies in the top ten countries:- Iraq, Pakistan, Afghanistan, India, Colombia, Philippines, United States, Peru, El Salvador and Somalia and the top region are the Middle East and North Africa, South Asia

# %% [markdown]
# ## **Chart - 6 Top 10 Weapon Used**

# %%
#getting top 5 the labels
#plt.subplots(figsize=(10,10))
labels=  df['Weapon_type'].value_counts()[:5].index
#getting the 5 values
data_values = df['Weapon_type'].value_counts()[:5].values

#pie-chart
plt.pie(data_values, labels = labels, autopct='%.0f%%')
plt.title("Tererrism Weapon")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# The pie chart is a special figure with coloured wedges that contains all the data. The distribution of the numerical information determines the size of every segment in a pie chart. It is a tool for analyzing numerical values and their compositions. So Pie-chart here will show the composition of the different weapons according to their use in the terrorism
#
# **2. What is/are the insight(s) found from the chart?**
#
# 50% of the weapons used are explosives. And second, a used weapon is Firearms and the least used weapon is Melee and others contribute 9 per cent to the terrorist attack
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Government should constrain the use of exploding material and should keep tracking Firearms. Only if these deadly weapons are controlled and tracked frequently can reduce terrorism in the World. Government should strictly handle these situations

# %% [markdown]
# ## **Chart - 7 Attack every year in every year**

# %%
# Chart - 7 Number of Attacks each year
country_df=df[['Country','Year']].copy()
country_wise=country_df.groupby(['Country','Year']).agg({'Country':'count'}).rename(columns={'Country':'total_attacks'}).sort_values(['Country','Year'], ascending=[True,False])
Country_final = country_wise.unstack().T
Country_final.reset_index(inplace= True)
Country_final_final = Country_final.loc[Country_final.Year > 2000,["Year","Iraq","Pakistan",'Afghanistan','India','Philippines','Somalia']]

plt.rcParams["figure.figsize"] = (12,9)
plt.plot(Country_final_final.Year, Country_final_final.Iraq, marker = 'o', label = "Iraq")
plt.plot(Country_final_final.Year, Country_final_final.Pakistan, marker = 'o', label = "Pakistan")
plt.plot(Country_final_final.Year, Country_final_final.Afghanistan, marker = 'o', label = "Afghanistan")
plt.plot(Country_final_final.Year, Country_final_final.India, marker = 'o', label = "India")
plt.plot(Country_final_final.Year, Country_final_final.Philippines, marker = 'o', label = "Philippines")
plt.plot(Country_final_final.Year, Country_final_final.Somalia, marker = 'o', label = "Somalia")

plt.title("Attack faced By Each Country From Year 2000-2017",fontsize=20,fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# **1.** List item
#
# **2.** List item
#
# A line chart is a type of chart that is used to show information that changes over time. The line chart plots the series of several points connecting them with a straight line. And these connecting lines are used to track changes over short and long periods. So this chart has plotted multiple lines in a single chart so that different trends can be compared and even studied individually over the data points changes over time.
#
# **2. What is/are the insight(s) found from the chart?**
#
# It could be seen that since 2000 that Iraq has faced most terrorism. All the country faced an increase in terrorism slightly but from 2009 it can be seen every county's attack has increased significantly among which Iraq's attacks has increased exponentially. But from 2014 all terrorism has been reduced wherein Pakistan terrorism has rapidly decreased
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# It could help more as it gives a significant year which is the year of dip and growth. This specific year should be studied more and find the reason why these points are like this and why they decrease.

# %% [markdown]
# ## **Chart - 8 Total Casualty done by the Different Methods of attack**

# %%
# Chart - 8 visualization code
df["Damage"] = df["Killed"] + df['Wounded']
damage_done = df.groupby('Attack_type',as_index = False).agg({'Damage':'sum'}).sort_values('Damage',ascending=False)
damage_done = damage_done.nlargest(5,'Damage')
my_labels = ["Bombing/Explosion",	"Armed Assault",	"Others",	"Assassination","Hijacking"]
plt.rcParams['figure.figsize']=(8,8)
explode=[0.05,0,0,0,0]
plt.pie(damage_done["Damage"],labels=my_labels,explode= explode, shadow=True, startangle= 60, autopct='%1.1f%%')
plt.title('Casulaty Done by Different Attack')
plt.axis('equal')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Pie Chart is a type of graph that represents the data in a circular graph with the slices of pie which shows the relative size of the data. Pieces of the graph are proportional to the fraction of the whole in each category. So we have chosen this chart as it will show the relative size of the casualty done by different types of attack in pie where each pie represents the damage caused by each Attack Type. And we can compare each attack and its damage composition.
#
# **2. What is/are the insight(s) found from the chart?**
#
# The insights found from the chart are:
#
# Bombing/Explosion has done the most damage. It contributes 58.3% of casualties to the total damage done by Terrorism.
# Hijacking and Assassination contribute least in the act of terrorism with 4.5% and 4.7% each.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# It can be seen that Bombing/Explosion and Armed Assault are the main cause of the major attack and also contribute to the happening of death and wounded people. So the Government should take some serious action and tilt toward more advanced technology which can detect explosives and assault rifles. Then only they can reduce the death and wounded.

# %% [markdown]
# ## **Chart - 9 Casulaty on the different Targets**

# %%
# Chart - 9 visualization code
df["Damage"] = df["Killed"] + df['Wounded']
target_df=df[['Target_type','Damage']].copy()
target_wise=target_df.groupby('Target_type').agg({'Target_type':'count','Damage':'sum'}).rename(columns={'Target_type':'total_attacks'}).sort_values('total_attacks',ascending=False)
target_wise.sort_values('Damage',ascending=False)
target_wise.reset_index(inplace = True)
plt.rcParams['figure.figsize']=(18,10)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
l=sns.barplot(x='total_attacks',y='Target_type',data=target_wise,palette='pastel')
l.set_title("Casulaty on the different Targets",fontsize=25,fontweight='bold')
l.set_xlabel('Casulaty',fontsize=20)
l.set_ylabel('Targets Types',fontsize=20)
# Out:
# Text(0, 0.5, 'Targets Types')

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Bar graphs have an X-axis and y-axis where one axis represents the categories and the other represents the scale. This chart is chosen because it can show the different bars according to the different lengths where each bar is proportional to the value that it represents. Here the x-axis represents the scale and the y-axis represents the categorical values.
#
# **2. What is/are the insight(s) found from the chart?**
#
# This graph represents:
#
# 1. Terrorist seems to attack Private citizens and property more and most casualty i.e Killed or Wounded
#
# 2. 2nd most attacks are done on the Military.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# We can certainly tell that terrorists are likely to kill and harm normal people and these monsters also tend to attack more on the military, police and government officials.

# %% [markdown]
# ## **Chart - 10 Top 10 Most Dangerous Gangs**

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'State', 'City',
#        'Attack_type', 'Target_type', 'Target_subtype', 'Gang_name',
#        'Weapon_type', 'Killed', 'Wounded', 'Damage'],
#       dtype='object')

# %%
# Taking the known Gang only
gname_country = df[df['Gang_name']!='Unknown'].copy()
group_attacks=gname_country.groupby(['Gang_name','Country']).agg({'Gang_name':'count'}).rename(columns={'Gang_name':'no_of_attacks'}).reset_index().nlargest(10,'no_of_attacks')
country_mode=gname_country.groupby('Gang_name')['Country'].apply(lambda x: x.mode().loc[0]).reset_index()
top_df = pd.merge(left=country_mode,right=group_attacks,on=['Gang_name','Country'],how='left').nlargest(10,'no_of_attacks')
top_df.sort_values('no_of_attacks',ascending=True,inplace=True)

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.rcParams['font.size'] = 20.0
a = top_df.plot(kind='barh', x='Gang_name',y ='no_of_attacks',fontsize=18)
a.set_xlabel('Total Number of Attacks',fontsize=15,fontweight='bold')
a.set_ylabel('Terrorist Group',fontsize=22,fontweight='bold')
x1=top_df.Country
y=top_df.no_of_attacks
b=a.twinx()
b.set_xlabel('Country')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15, rotation=90)
plt.xlabel('Number Of Attacks', fontsize=20)
plt.ylabel('Country', fontsize=20,fontweight='bold')
plt.title('Top 10 Terrorist Groups With Most No. of Attacks And The Countries They Prefered', fontsize=25,fontweight='bold')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# This is the bar graph with dual Axes which have a shared axis but also an independent axis. So here we have set the bar graph which represents the highest number of attacks and also tells about those attacks that happens in which country.
#
# **2. What is/are the insight(s) found from the chart?**
#
# The chart clearly tells that Most active group in the world is the Taliban which mostly attacks in Afghanistan.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# These graphs represent the most active terrorist group Taliban in Afghanistan and they should take preventive measures in the country. Needs to do bilateral talks with the Taliban. And also give attention towards other top terrorist groups according to the country.

# %% [markdown]
# ## **Chart - 11 No attack in Each year in India -1970-2017**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already loaded the data into the 'df' DataFrame

# Selecting the data for India
India = df[df['Country'] == 'India']

# Checking if the 'Year' column exists in the DataFrame 'India'
if 'Year' in India.columns:
    plt.figure(figsize=(18, 10))
    sns.countplot(x='Year', data=India)
    plt.title('Terrorist Attack Each Year in India')
    plt.xticks(rotation=45)
    plt.show()
else:
    print("Column 'Year' not found in the DataFrame 'India'. Please check your data.")

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# The count plot represents the count of the categorical data with rectangular bars with heights or lengths proportional to the frequency of each variable. Here we have represented the number of terrorist attacks each year and the height of the bar is proportional to the number of attacks every year.
#
# **2. What is/are the insight(s) found from the chart?**
#
# From the given data, before 1977 India was a peaceful country but terrorist activities started in 1977 and it keeps increasing rapidly though some years like 1984,1998,2004 show a great decline in the attack. And terrorism attacks skyrocketed in 2008 and 2016.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# It shows that terrorism is not going to stop, it seems to increase year by year. So the Indian Government should move to deep research on the dip and rise year, so they can identify the main problem of terrorism and could eliminate this inhuman thing.

# %% [markdown]
# ## **Chart - 12 Top 10 cities of Terrorist Attacks in India**

# %%
#selecting the country India
India = df[df['Country']=='India']

# %%
# Chart - 12 visualization code
#selecting all the City except the "Unknown"
new_india  = India[India['City'] != 'Unknown']
#Getting the City name and number of attack in it
data = new_india['City'].value_counts()[:10].values
label = new_india['City'].value_counts()[:10].index
plt.figure(figsize = (18,10))
sns.barplot(data = new_india,x = label,y = data)
plt.title('Terrorist Attack Each Year')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# This graph is chosen because it represents an estimate of the central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars. So these charts plot the cities and their count
#
# **2. What is/are the insight(s) found from the chart?**
#
# This chart represents that Srinagar is the most prone to terrorism area in India and Impheral and New Delhi are in the descending order.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Here The graph tells that terrorism attack happens mostly in Srinagar so Government should invest more time, facilities and deploy more forces in the Srinagar.

# %% [markdown]
# ## **Chart - 13 Russia and Ukraine**

# %%
# Chart - 13 visualization code
fig,ax = plt.subplots(figsize=(15,6))
russia = df[(df['Country']=='Russia') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()
ukraine = df[(df['Country']=='Ukraine') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()

sns.lineplot(x=russia.index,y=russia.values)
sns.lineplot(x=ukraine.index,y=ukraine.values)

plt.xticks(np.arange(2000,2017,1))
plt.xlim(2000,2017)
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Russia VS Ukraine (2000-2017)')
ax.legend(labels=['Russia','Ukraine'])
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# A line chart is a form of graphical representation of data in the form of points that are joined continuously with the help of a line. The line can either be straight or curved depending on the data being researched. line charts are the simplest form of representing qualitative data between two variables that are shown with the help of a line that can either be straight or curved. So to study the rise of the attack in Russia and Ukraine in the same plot multiple-line charts are chosen.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Russia has fluctuated in the attack from time to time but Ukraine seems to be constantly very less affected by the terrorist attack until the year 2014 the terrorist attack skyrocketed because Russia annexed Crimea, and after 2015 the attack dropped rapidly.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# War can increase terrorist attacks. So these Different countries should focus on not to involve in any kind of war

# %% [markdown]
# ## **Chart - 14 Relation between the SAARC Countries**

# %%
# Chart - 14 visualization code
fig,ax = plt.subplots(figsize=(15,6))

Pakistan = df[(df['Country']=='Pakistan') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()
India = df[(df['Country']=='India') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()
Afghanistan = df[(df['Country']=='Afghanistan') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()
Nepal = df[(df['Country']=='Nepal') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()
Bangladesh= df[(df['Country']=='Bangladesh') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()
Bhutan = df[(df['Country']=='Bhutan') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()
Sri_lanka = df[(df['Country']=='Sri Lanka') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()
Maldives = df[(df['Country']=='Maldives') & (df['Year'].between(2000,2017,inclusive=True))]['Year'].value_counts()

sns.lineplot(x=Pakistan.index,y=Pakistan.values)
sns.lineplot(x=Pakistan.index,y=India.values)
sns.lineplot(x=Afghanistan.index,y=Afghanistan.values)
sns.lineplot(x=Nepal.index,y=Nepal.values)
sns.lineplot(x=Bangladesh.index,y=Bangladesh.values)
sns.lineplot(x=Bhutan.index,y=Bhutan.values)
sns.lineplot(x = Sri_lanka.index, y =Sri_lanka.values)

plt.xticks(np.arange(2000,2017,1))
plt.xlim(2000,2017)
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('SAARC  (2000-2017)')
ax.legend(labels=['Pakistan','India','Afganistan','Nepal','Bangladesh','Bhutan','Sri Lanka'])
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# This chart is used because this could show the number of attack per year. And multiple countries' lines can be drawn in the same graph so that we can make lots of comparisons and studies.
#
# **2. What is/are the insight(s) found from the chart?**
#
# From early 2000 SAARC seems to be less tilted toward terrorism attacks but India was still facing some problems of terrorist attack. But things started to change from 2006 and these attacks kept on increasing. Most affected are Pakistan, Afghanistan and India. After 2014 Afghanistan became the most affected country till 2017 even its attack has reduced.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# All the countries' attack rate has decreased rapidly but in Afghanistan, it just decreased slightly so Afghanistan needs to take special military force and should take help from another country in terms of resources, army, and technology or it could do harm in future. And need not invest in the countries having fewer attacks throughout this period

# %% [markdown]
# ## **Chart - 14 - Correlation Heatmap**

# %%
# Going to the original dataset with the preferred columns
df.drop('Damage', axis=1,inplace = True)

# %%
 ## Correlation
plt.figure(figsize=(8,5))
correlation = df.corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Correlation heatmaps are that kind of plot which visualize the strength of relationships between different numerical variables. Correlation plot are often used to understand which variables are related to each other.These are mostly used so that it can find the potential relationships between variables. The depth of colour-coding of the cells makes it easier to identify how strong the relationship is between them. It is used to find linear and non-linear relationships.
#
# **2. What is/are the insight(s) found from the chart?**
#
# The graph insight the weak corelationship between the different variables. Killed and Wounded has just less than 0.44 corelation.

# %% [markdown]
# ## **Chart - 15 - Pair Plot**

# %%
# Pair Plot visualization code
sns.pairplot(df)

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Pair plot allows us to plot pairwise relationships between variables within a dataset and it also creates a nice visualisation and helps us understand the data by summarising a large amount of data in a single figure. This is essential for exploring our dataset and trying to become familiar with it. So it will produce figures of all the variables present in the dataset along with the y and x axis. And diagonal shows the histogram showing the distribution of each of the variables.
#
# **2. What is/are the insight(s) found from the chart?**
#
# The above charts have a very less linear relationship between variables and their data points so they are not linearly separable. The above variables seem to have correlated with each other maybe because they have mostly categorical variables.

# %% [markdown]
# # **5. Data Driven Solution to Business Objective**

# %% [markdown]
# ### **What do you suggest the client to achieve Business Objective ?**
#
# Explain Briefly.
#
# Solution based on EDA:-
#
# Developed countries need to bring refugees from the most affected countries.
#
#  Because a city like Baghdad has more attacks than the whole world combined.
#
# Explosives and guns need to be controlled & Monitored
#
# Explosive and gun detection systems need to be implemented
#
# Bunker should be made in public areas
#
# Most affected countries need to adopt modern technology
#
# Should make a strong network of the spy to monitor them and try to stop the future attack
#
# Implementation of more military personnel and security in the most affected cities
#
# Needs cooperation from the neighbouring and developed countries
#
# Need to conduct the bilateral Talk with the Terrorist Gangs

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The withdrawn conclusion are :
#
# Terrorist attack has been increasing since 1970 but in 2012 attacks increased exponentially
#
# Baghdad is the hotspot of terrorism as it has the most number of attacks in the entire world.
#
# Iraq is the country with the most number of Attack happens mainly due to the Taliban, and also responsible for several casualties i.e Killed wounded and damaged
#
# Middle East & North Africa is the most affected region.
#
# Year with the most attacks is 2014 and the most active month is 5 i.e May and Day is 15
#
# Most used weapons are Explosive and Arms Assault among which 50% of the attacker has used explosive weapon to attack and about 58.3 % of casualty has been by Bombing/Explosion ArmAsult has also been used to kill and wound the people
#
# But in countries like El Salvador and the Philippines Arm Assault has been used as the main weapon wherein Hijacking & Assassination contribute less.
#
# Most targeted is private Citizens & Property such as unarmed man, mall, roads etc
#
# Most active Terrorist Gangs is the Taliban which is from Afghanistan
#
# After 1977, terrorist attacks started in India and skyrocketed in 2008 and went to peak in the year 2016
#
# Srinagar is the most affected city in India
#
# In Russia and Ukraine, the attacks started to increase from the year 2014 due to the annexation of the Cremia.
#
# In SAARC countries Pakistan, Afghanistan and India seem to have more terrorist attacks than the rest of the SAARC countries.
#
# Total number of Terrorist groups is 3537
