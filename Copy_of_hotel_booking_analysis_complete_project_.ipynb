# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshkekane/Cosumer-Loan-Assistant-Master/blob/master/Copy_of_hotel_booking_analysis_complete_project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name - Hotel Booking Analysis**
#
# ---
#
#
#
# **Project Type - EDA**
#
# ---
#
#
# **Contribution - Team**
#
# ---
#
#
# **Team member 1 - Jayraj Songire**
#
# ---
#
#
# **Team member 2 - Rushikesh Kekane**
#
# ---
#
#
# **Team member 3 - Shantanu Walunj**
#
# ---
#
#
# **Team member 4 - Sunil Pathak**
#
# ---
#
#
# **Team member 5** -

# %% [markdown]
# # **Project Summary-**
#
# Hotel Booking Analysis Project Summary
#
# 1. In this Project we began to explore the dataset in which Hotel Booking comprises of two type of hotels i.e **City Hotel** and **Resort Hotel**.
# 2. In this dataset there are 119390 rows and 32 columns.
# 3. All the columns are divided into three dtype - Object,Float & Int
# 4. This Datasheet does have duplicate as well as null values. There are total of 31994 duplicate values and 4 columns have missing values.
# 5. the maximum number of missing values are from "company" column then followed by "Agent", "Country" and "Children" columns. the "children" column consists of only 4 null values while "company" column consist of 112593 null values. the total rows are 119390 and columns are 32.
# 6. In this project we have divide the data manipulation workflow into three different categories i.e Data collection, Data cleaning and manipulation and EDA.
# 7. In moving further we have used various basic function and attributes i.e
# Data collections first step to find different columns which is done by using various method like Head(),tail(),info(),describe(),columns(),and some others method used for data collection.
# 8. In this dataset there are both duplicate and missing values available. so we have to deal with that and as a result we have replaced the null and missing values and also have droped the duplicate values.
# 9. The further we converted the datatype of columns into appropriate datatype. we also added some columns. this dataset was also containing duplicate values so we dropped this.
# 10. We have found there were some rows in which values of adults, babies and children was 0 so this simply means there were no guests as 0 indicate presence of none. so there were no bookings made.  as a result, we simply dropped that rows where combining values for adults, babies, children columns was 0.
# 11. The datatype of 'reservation_status_date' column was object type so it was changed to date type format for better use. there were two new columns that was added, one is 'total_people' and other is 'total_stay'.
# 12. Before visualizing any type of data from the data set we need to do data wrangling so for that we have to checked null value of the columns so after completing the process of data visualizing we move to data visulizion part.

# %% [markdown]
# # **GitHub Link-**
# -

# %% [markdown]
# # **Problem Statement**
#
# **Have you ever wondered when the best time in a year to book a hotel room is? or the optimal length of stay in order to get best daily rate? what if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special request?
# this hotel booking dataset can help you explore those questions. this data contain booking information of city hotel and resort hotel and includes information such as when booking was made, length of stay, the number of adult, children, babies etc.**

# %% [markdown]
# **Define your Business objective**
#
# Discovering the important factors and that govern booking and explore and analysis the data for business output.

# %% [markdown]
# # **Let's Begin!**
#
# # **1. Know Your Data**
#
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from datetime import datetime
import seaborn as sns
import folium
import plotly.express as px
# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
hotel_df = pd.read_csv('/Hotel Bookings csv file.csv')

# %% [markdown]
# ## **Dataset First View**

# %%
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ## **Dataset Rows and Columns count**

# %%
hotel_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ## **Dataset Information**

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ## **Duplicate Values**

# %%
len(hotel_df[hotel_df.duplicated()])
# Out:
# 31994

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=hotel_df.duplicated())
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## **Missing values/Null Values**

# %%
print(hotel_df.isnull().sum().sort_values(ascending=False))
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(hotel_df.isnull(),cbar=False,cmap='viridis')
plt.xlabel('Name of columns',fontsize=14)
plt.title('Place of missing values in column',fontsize=14)
# Out:
# Text(0.5, 1.0, 'Place of missing values in column')

# %% [markdown]
# ### **What did you know about your Dataset?**
#
# 1. This dataset contain 119390 rows and 32 columns.
#
# 2. All the columns are divided into three type i.e object,float64, int64.
#
# 3. This datasheet does have duplicate as well as null values. there are 31994 duplicate values and 4 columns have missing values.
#
# 4. The maximum number of missing values are from 'company' column then followed by 'Agent', 'country'and 'children' columns. the 'children' column consist of only 4 null values 'company' column 112593 null values.

# %% [markdown]
# # **2. Understanding of our variables**

# %%
print(hotel_df.columns)
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # **Variables Description**

# %% [markdown]
# 1. hotel: Name of the hotel(Resort and City Hotel).
# 2. is_canceled: if the booking was cancelled(1) or not cancelled (0).
# 3. lead_time: Number of days that elapsed between the entering date of the booking into the PMS and the arrival date.
# 4. arrival_date_year: year of the arrival date.
# 5. arrival_date_month: Month of month arrival date.
# 6. arrival_date_week_number: Week number of arrival date.
# 7. arrival_date_day_of_month: Day of arrival date.
# 8. stays_in_weekend_nights: Number of weekend nights(Saturday and Sunday)the guest stayed or booked to stay at the hotel.
# 9. stay_in_weeknights: Number of weeknights(Mon to Fri)the guest stayed or booked to stay at the hotel.
# 10. adults: Number of adults among guests.
# 11. children: Number of children among guest.
# 12. babies: Number of babies among guests.
# 13. meal: kind of meal opted for.
# 14. country: Country code.
# 15. market_segment: Which segment customer belongs to .
# 16. distribution_channel: Name of the booking distribution channel The term 'TA' means 'travel agents'&'TO' means 'Tour Operators'.
# 17. is_repeated_guest:if the booking was done from a repeated guest(1) or not (0).
# 18. previous_cancellation: Number of previous booking that were cancelled by the customer prior to the current booking.
# 19. previous_booking_not_canceled: Number of previous booking not cancelled by the customer prior to the current booking.
# 20. reserved_room_type: Code of room type reserved.
# 21. assigned_room_type: Code of room type assigned.
# 22. booking_chareges: Number of the charges/amendments made to the booking.
# 23. deposite_type: Type of the made by the guest.
# 24. agent: ID of the company that made the booking.
# 25. company: ID of the company that made that booking.
# 26. days_in_waiting_list: Number of days the booking was in the waiting list.
# 27. customer_type: Type of customers,assuming one of the four categories.
# 28. adr:Average daily rate.
# 29. required_car_parking_space: Number of the car parking spaces required by the customer.
# 30. total_of_special_request: Number of special request made by the customer.
# 31. reservation_status: Reservation status.
# 32. reservation_status_date: Date at which the last reservation status was updated.

# %% [markdown]
# # **Check unique values for each variables.**

# %%
for i in hotel_df.columns.tolist():
  print("Number of unique value is", i ,"is",hotel_df[i].nunique())
# Out:
# Number of unique value is hotel is 2
# Number of unique value is is_canceled is 2
# Number of unique value is lead_time is 479
# Number of unique value is arrival_date_year is 3
# Number of unique value is arrival_date_month is 12
# Number of unique value is arrival_date_week_number is 53
# Number of unique value is arrival_date_day_of_month is 31
# Number of unique value is stays_in_weekend_nights is 17
# Number of unique value is stays_in_week_nights is 35
# Number of unique value is adults is 14
# Number of unique value is children is 5
# Number of unique value is babies is 5
# Number of unique value is meal is 5
# Number of unique value is country is 177
# Number of unique value is market_segment is 8
# Number of unique value is distribution_channel is 5
# Number of unique value is is_repeated_guest is 2
# Number of unique value is previous_cancellations is 15
# Number of unique value is previous_bookings_not_canceled is 73
# Number of unique value is reserved_room_type is 10
# ...

# %%
#checking the unique value one by one
#checiking unique value of 'hotel'
hotel_df['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
#checking unique value of 'arrival_date_year'
hotel_df['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017])

# %%
#checking unique value of 'is_canceled'
hotel_df['is_canceled'].unique()
# Out:
# array([0, 1])

# %%
#checking unique value of 'meal'
hotel_df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
#checking unique value of 'distribution_channel'
hotel_df['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
#checking unique value of 'market_segment'
hotel_df['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
#checking unique value of 'children'
hotel_df['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %% [markdown]
# # **3. Data Wrangling**
#
# Data wrangling code

# %%
# write your code to make your dataset analysis ready

# missing value in columns
hotel_df.isnull().sum().sort_values(ascending=False)[:5]
# Out:
# company               112593
# agent                  16340
# country                  488
# children                   4
# reserved_room_type         0
# dtype: int64

# %%
# Replacing null values of agent, company, and children with value 0 and replacing null values of country column with other
hotel_df[['company','agent','children']] = hotel_df[['company','agent','children']].fillna(0)
hotel_df[['country']] = hotel_df[['country']].fillna('other')

# %%
# checking
hotel_df.isnull().sum().sort_values(ascending=False)[:5]
# Out:
# hotel                          0
# is_canceled                    0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# dtype: int64

# %%
#checking no of duplicate values in dataset
len(hotel_df[hotel_df.duplicated()])
# Out:
# 31994

# %%
#droping duplicate values
hotel_df = hotel_df.drop_duplicates()
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#checking the shape of dataset whose combining values of adults, babies and children column is 0
hotel_df[hotel_df['adults']+hotel_df['babies']+hotel_df['children']==0].shape
# Out:
# (166, 32)

# %%
#checking the shape of new updated dataset
hotel_df.shape
# Out:
# (87396, 32)

# %%
#creating the copy of dataset for further analysis
hotel_df1 = hotel_df.copy()

# %%
#droping the rows where combining values of adults, babies and children column is 0 because that mean no booking were made.
hotel_df1.drop(hotel_df1[hotel_df1['adults']+hotel_df1['babies']+hotel_df1['children']==0].index,inplace=True)

# %%
#changing datatype of column 'reservation_status_date' from object to date_type
hotel_df1['reservation_status_date']= pd.to_datetime(hotel_df1['reservation_status_date'],format= '%Y-%m-%d')

# %% [markdown]
# # **Adding Important Column**

# %%
#adding 'total_stays' in hotel
hotel_df1['total_stays'] = hotel_df1['stays_in_weekend_nights'] + hotel_df1['stays_in_week_nights']
#adding total number of people
hotel_df1['total_people'] = hotel_df1['adults']+hotel_df1['children']+hotel_df1['babies']

# %%
#checking the shape of dataset
hotel_df1.shape
# Out:
# (87230, 34)

# %% [markdown]
# # **What all manipulations have you done and insights you found?**

# %% [markdown]
# **Manipulations and the insights found by us are as follows**

# %% [markdown]
# * We found that there were four columns containing null values so we had null values in columns- Company, Agent, Country and Children.
#
# 1. So for company,children and agent we have filled the missing values with 0.
# 2. For country, We have fill missing values with object 'Others'.
# 3. As the count of missing values in children Column was only 4, so it was replaced with 0 considering no children.
#
# * This dataset also containing the duplicate values so dupplicate values is dropped.
#
# * We found that there were some rows in which the combining values of adults,babies, and children was 0 so this simply there were no guests as 0 indicates presence of none. SO, there were no booking made. as a result, We dropped the rows where combining values of adults, babies and children columns was 0.
#
# * The data type of 'reservation_status_date' is changed from object data type to data type format for better use.
#
# * There were two new columns are added, one is 'total_stays' and other is 'total_people'.

# %% [markdown]
# # **4. Data vizualization, Storytelling and Experimenting with chart : Understand the relationships between variable**
#
# ## **Chart-1 Pie chart for most preferred hotel.**

# %%
hotel_df1['hotel'].value_counts().plot.pie(explode=[0.05,0.05],autopct='%1.1f%%', shadow=True, figsize=(8,6),fontsize=18)
plt.title('pia chart for most preffered hotel', fontsize=15)
# Out:
# Text(0.5, 1.0, 'pia chart for most preffered hotel')

# %% [markdown]
# **1.** **Why did you pick the specific chart?**
#
# To prevent the data that in which hotel more booking have been done.
#
# **2.** **What is/are the insight(s) found from the chart?**
#
# Here, we found that the booking number is Higher in City Hotel which is 61.10% than Resort hotel which is 38.9%. Hence we can say that City hotel has more consumption.
#
# **3.** **Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, for both Hotels, this data making some positive business impact.
#
# City Hotel :- Provided more services to attract more guest to increase more revenue.
#
# Resort Hotel :- Find solution to attract guest and find what city hotel did to attract guest.

# %% [markdown]
# ## **Chart- 2 Hotel type with highest adr (Bivariate with Categorical-Numerical).**

# %%
#chart-2 visualization code
group_by_hotel = hotel_df1.groupby('hotel')

# %%
#Group by hotel adr
highest_adr = group_by_hotel['adr'].mean().reset_index()
#set plot size
plt.figure(figsize=(10,8))
#set the x,y and title table
plt.xlabel('hotel type',fontsize=15)
plt.ylabel('ADR',fontsize=15)
plt.title("avg ADR of each hotel type",fontsize=15)
#plot the graph
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])
# Out:
# <Axes: title={'center': 'avg ADR of each hotel type'}, xlabel='hotel', ylabel='adr'>

# %% [markdown]
# **1.** **Why did you the specific chart?**
#
# To show the average adr of each hotel type in a clear and feasible way.we have used bar chart.
#
# **2.** **What is/are the insight(s) found from the chart?**
#
# City hotel has the highest ADR.This  means city hotel generates the more revenue than the resort hotel. More the ADR more the revenue.
#
# **3.** **Will the gained insights help creating a positive business impact?**
#
#  there any insights that lead to negative growth? Justify with specific reason.
#
# City hotel can do more advertising to get more customers that will ultimately add up to their revenue.City hotel already earning more but positive efforts towards growth will definitely adds alot to growth averall revenue.

# %% [markdown]
# ## **Chart 3- Relationship between ADR and Total stay.**

# %%
#chart-3 visualization code
adr_and_stay = hotel_df1.groupby(['total_stays','adr','hotel']).agg('count').reset_index()
adr_and_stay = adr_and_stay.iloc[:,:3]
adr_and_stay = adr_and_stay.rename(columns={'is_canceled':'number of stays'})
adr_and_stay = adr_and_stay[:18000]
adr_and_stay
# Out:
#        total_stays     adr         hotel
# 0                0    0.00    City Hotel
# 1                0    0.00  Resort Hotel
# 2                1    0.00    City Hotel
# 3                1    0.00  Resort Hotel
# 4                1    1.00    City Hotel
# ...            ...     ...           ...
# 17995            7  212.06    City Hotel
# 17996            7  212.10  Resort Hotel
# 17997            7  212.14  Resort Hotel
# 17998            7  212.29    City Hotel
# 17999            7  212.29  Resort Hotel
#
# [18000 rows x 3 columns]

# %%
#ploting the graph in the chart
plt.figure(figsize=(12,6))
sns.lineplot(x='total_stays',y='adr',data=adr_and_stay)
plt.xlabel('total_stays',fontsize=15)
plt.ylabel('ADR',fontsize=15)
plt.title('Relationship between ADR and Total stays',fontsize=14)
# Out:
# Text(0.5, 1.0, 'Relationship between ADR and Total stays')

# %% [markdown]
# **1.** **Why did you pick the specific chart?**
#
# This is the line chart and help to show small show or slight change in graph is easy to spot. So we can easily track the ups and downs of the graphs.
#
# **2.** **What is/are the insight(s) found from the chart?**
#
# in this linechart we observe that total stay increase than the ADR is also increase,i.e total stays is directly proportional to the ADR.
#
# **3.** **Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# So, the hotels focus on incresing their ADR and more advertisiment and better facilities and good offers will let the guest to stay more that will directly affect on ADR.Hotels should do more advertisment and increasing facilities so that total stay will increase.

# %% [markdown]
# ## **Chart-4 Which month have most people prefer to visit.**

# %%
# Chart-4 visualization code
hotel_df1['arrival_date_month'].value_counts().plot.pie(autopct='%2.1f%%',shadow=False,figsize=(14,8),fontsize=20,labels=None)
plt.title("% months of people prefer to visit hotel ")
labels=hotel_df1['arrival_date_month'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# **1.Why did you pick the specific chart?**
#
# I want to know month in which people visit to both hotels.
#
# **2. What is/are the insight(s) found from the chart?**
#
# It is found that 'august' month is most busiest month.
#
# **3.Will the gained insights help creating a positive business impact?**
#
#  there any insights that lead to negative growth? Justify with specific reason.
#
# I found that 'august' is most crowded so hotels should have focus on other months

# %% [markdown]
# ## **Chart 5- what is reservation status of both the hotels?**

# %%
# Chart-5 visualization code
hotel_df1['reservation_status'].value_counts().plot.pie(autopct='%2.1f%%',shadow=False,figsize=(14,8),fontsize=20,labels=None)
plt.title("% reservation status")
labels=hotel_df1['reservation_status'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# I want to know reservation status of peoples
#
# **2. What is/are the insight(s) found from the chart?**
#
# it is found that most of peoples are checked out.
#
# **3. Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# It will create positive impact because we can increase bookings if persons are checked out

# %% [markdown]
# ## **Chart 6- What is the percentage of most repeated guests?**

# %%
# Chart-6 visualization code
hotel_df1['is_repeated_guest'].value_counts().plot.pie(explode=(0.05,0.05),autopct='%1.1f%%',shadow=True,figsize=(10,8),fontsize=20,)
plt.title('Percentage (%) of repeated guests',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percentage (%) of repeated guests')

# %% [markdown]
# **1.** **Why did you pick the specific chart?**
#
# Pie chart are used to represent the proportional data or relative data in single chart.This pie chart is showing percentage of repeated guest or repeated guest and 1 is repeated guest through pie chart with different area under circle.
#
# **2.** **What is/are the insight(s) found from the chart?**
#
# Repeated guest is very few which is only 3.9% while 96.1% of guest not returning the same hotel. So its matter of thinking and proper steps to increase the number of repeated guest.In order to increase to retained the guest management should take feedback from guests and try to improve the service.
#
# **3.** **Will the gained insights help creating a positive business immpact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes the propportion of repeated guest is very much low so if hotels work well then tthe increase in no of repeated guests will ultimately boost their revenue so Hotels can give alluring affers to non-repeating customers during off season to enhance revenue.So right steps should be taken like talking feedbacks,solving problems of customenrs within time limit and offering best offers to the customers.

# %% [markdown]
# ## **Chart 7- which category of meal most preffered by guest**

# %%
# Chart-7 visualization code
plt.figure( figsize=(7, 5))

sns.countplot(x = hotel_df1['meal'])
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# this is count plot chart to get clear insights about the counts of different types of meal, we have used this count plot.
#
# **2. What is the insights found from the chart?**
#
# The insights thet count plot graph is that most preferred meal type by the guest is 'BB'(Bead and Breakfast) and 'FB'(Full Board) is the least prefered meal type by the guest.
#
# **3. will the gained insights help creating a positive impact?**
#
#   Are there any insights that lead to negative growth? justify with specific reason.
#
#  So insights here also have positive impact as hotels need to focus more on the BB meal type so that the majority of coustmers are satisfied while other type of meal should be given equal importance with proper management of food service so as to offer best services so as to offer best services to coustmers.

# %% [markdown]
# ## **Chart 8- Booking by month and optimal stay length in hotels**

# %%
#chart 8- visualization code
#using groupby on arrival_date_month and taking the hotel count
booking_by_months_df = hotel_df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':'counts'})
#create list of months in order
months= ['January','February','March','April','May','June','July','August','September','October','November','December']
#creating df which will map the order of above months list without changing its value.
booking_by_months_df['arrival_date_month'] = pd.Categorical( booking_by_months_df['arrival_date_month'],categories=months,ordered=True)
#sorting by arrival_date_month
booking_by_months_df=booking_by_months_df.sort_values('arrival_date_month')
booking_by_months_df
# Out:
#    arrival_date_month  counts
# 4             January    4685
# 3            February    6083
# 7               March    7489
# 0               April    7900
# 8                 May    8344
# 6                June    7756
# 5                July   10043
# 1              August   11242
# 11          September    6682
# 10            October    6921
# 9            November    4973
# 2            December    5112

# %%
#set plot size
plt.figure(figsize=(18,8))
#ploting lineplot
sns.lineplot(x=booking_by_months_df['arrival_date_month'],y=booking_by_months_df['counts'])
#set title for plot
plt.title('Number of booking across each month', fontsize=12)
#set x label
plt.xlabel('Month', fontsize=12)
#set y label
plt.ylabel('Number of Bookings',fontsize=12)
# Out:
# Text(0, 0.5, 'Number of Bookings')

# %%
#useing groupby function on total stay hotel
stay = hotel_df1.groupby(['total_stays','hotel']).agg('count').reset_index()
#taking only first three column
stay = stay.iloc[:,:3]
#renaming the column
stay = stay.rename(columns={'is_canceled':'Number_of_stays'})

# %%
#setting plot size barchart
plt.figure(figsize=(20,10))
sns.barplot(x='total_stays',y='Number_of_stays',hue='hotel',data=stay)
#set label
plt.title('optimal stay length in both hotel types',fontsize=15)
plt.ylabel('Count of stays',fontsize=15)
plt.xlabel('Total_stay(days)',fontsize=15)
# Out:
# Text(0.5, 0, 'Total_stay(days)')

# %% [markdown]
# **1.** **Why did you pick the specific chart?**
#
# For 1st chart we have picked the line chart here because it helps to show small shifts that may be getting hard to spot in other graphs.It helps different preiods.They are easy to understand  so, here we can easily track the change of number of bookings lwith respect to month.
#
#
# In 2nd chart the bar plot has been used.We have used this chart to get clear view in understanding the relation between total stay in terms of chart.
#
# **2.** **What is/are the insight(s) found from the chart?**
#
# In the first chart we have found that july and august had the most Bookings.As july and August generally surrounds in aand near summer vacation.So,Summer vacation can be the reason.
#
# In the second chart we found that optimal stay in bith the type hotel is less than 7 days.So after that staying numbers have declined.
#
# **3.**  **Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes this provides good insights that hotels should well prepared for the month of july and August as maximum booking take place in this month.So bettter the preparation and good approach will definately adds to growth of Hotels.
#
# While 2nd chart also have positive impact.Yes from the imsights gathered here, hotels can work in the domain to increase the staying length of customer to increase their revenue. The other understanding is that customers usually prefers a one week stay in hotels need to work efficiently in these seven days so that customers would return to same hotels again so this will increase the hotel revenue.

# %% [markdown]
# ## **Chart 9- Plotting Histogram**

# %%
#chart 9- visualization code
hotel_df1.hist(figsize=(24,18))
plt.show()

# %% [markdown]
# **1.** **Why did you pick the specific chart?**
#
# To understanding the data in clear way with proper insights, I have used the histogram here. Itr is used to summarize discrete or continued data an interval scal.It is often used to illustrate the major features of te distribution of the data in convenient form. It is also useful when deadline (greater than 100 observation).It can help detect any unusual observtion (outliers)or any gaps in the data. Thus we have used the histogram plot to analysis the variable distribution over the whoe dataset whether it's symmertric or not.
#
# **2.** **What is/are the insight(s) found from the chart?**
#
# Some insights found the chart as follows:
#
# 1. We can see that the maximum guest came in the year 2016.
# 2. Maximum arrival week number in 30.
# 3. Maximum arrival happpens in the last of month.
# 4. Maximum guests comes with no children.
# 5. There is very less requrement of car parking spaces.
#
# **3.** **Will the gained insights help craeting a positive business impact?**
#
# Are there any insights that lead to negative growth? justify with specific reason.
#
# Just histogram cannot defines business impact. Its done just to see the distribution of the column data over the dataset.

# %% [markdown]
# ## **Chart 10-  Year and Hotel wise confirmed booking and cancellation distribution**

# %%
#chart 11- visualization code
#plotting a count plot chart using  seaborn for counts of confirmed and cancelled booking
plt.figure(figsize=(14,6))
sns.countplot(x='hotel',hue='is_canceled',palette='Set2',data=hotel_df1)
plt.legend(['confirmed','canceled']) 
plt.title("Hotel wise confirmation and cancellation of the booking",fontsize=20)
plt.xlabel("Hotel",fontsize=15)
plt.ylabel("count of confirmation and cancellation",fontsize=15)
# Out:
# Text(0, 0.5, 'count of confirmation and cancellation')

# %%
#Removing the cancelled booking from data and creating a new dataframe
data_not_canceled = hotel_df1[hotel_df1['is_canceled']==0]
#year wise booking of hotel
sns.set_style(style='darkgrid')
plt.figure(figsize=(12,5))
sns.countplot(x='arrival_date_year',hue='hotel',palette='tab10',data=data_not_canceled)
plt.legend(['Resort Hotel','City Hotel'])
plt.title('Year wise booking of hotels',fontsize=18)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Number of booking',fontsize=15)
# Out:
# Text(0, 0.5, 'Number of booking')

# %% [markdown]
# **1.** **Why did you pick the specific chart?**
#
# We have picked out the count plotant and year wise booking in countplot.
#
# **2.**  **What is/are the insight(s) found from the chart?**
#
# We can clerly deduce from the above graphs that the city hotel is having greater number of bookings as compared to Resort hotel. But we can clerly sees that number of cancellation in city hotel is higher that the resort hotel.
#
# From the abovve graphs, it can be summarised that in the year  2016 both the hotel saw a massive in their bookings and by far the highest number of bookings.
#
# **3.** **Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Overall the graphs show the positive impact.But the cancellation rate of the city hotels creates a situation of deep concern.Thus, we need to look over this problem. The solution to this problem is taht we can check the reasons of cancellation of a booking & need to get this sorted out as soon as possible at the business level to stop the problems getting broader.

# %% [markdown]
# ## **Chart 11- Room type preference and Customer types**

# %%
#chart 11- visualization code
plt.figure(figsize=(20,10))
#ploting seaborn countploting
sns.countplot(x=hotel_df1['assigned_room_type'],order=hotel_df1['assigned_room_type'].value_counts().index)
#set xlabel for the plot
plt.xlabel('Room Type',fontsize=15)
#set ylabel for the plot
plt.ylabel('Count of Room Type',fontsize=15)
#set title for the plot
plt.title("Most preferred Room Type",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Most preferred Room Type')

# %%
#using seaborn to plot a count plot chart to demonstrate the types of customers visit the most 
plt.figure(figsize=(16,7))
sns.countplot(x='arrival_date_month',hue='customer_type',palette='Set2',data=hotel_df1)
plt.title('Type of customer arrived month wise',fontsize=18)
plt.xlabel('Number of customers',fontsize=15) 
plt.ylabel('Months',fontsize=15)
# Out:
# Text(0, 0.5, 'Months')

# %% [markdown]
# **1.** **Why did you pick the specific chart?**
#
# For, 1st cisulization, we have picked the bar chart to display result for this set of code. Here i have used bar graph to show distribution of volumn (count of rooms), which type of room is alloted. Bar graph summarise the large set of data in visuall form.It clarifies the trend of data than the table.So we can used the bar graph.
#
# While 2nd visualization involves a count plot because it helps us to get clear the total number of guests visited.So, we have use count plot here to know about the type of guests.
#
# **2.** **What is/are the insight(s) found from the chart?**
#
# From the above chart it is found that the most preferred Room type is "A". Majority of people show the intrest on the type"A" is most preferred guests.
#
# From the above graph it can be summarised that the Transient type of customers visit the most whereas the visitors who are in group comes in the category of least visitors.
#
# **3.** **Will the gained insights help creating a positive business impact?**
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, From the graph,it can be seen that there are positive impacts because 'A'D'E' is more preferred by guest due to better services offered in room type. So overall boooking in a hotel matters So, each room type belongs to each hotel so wherever customers goes the hotel will be benefit but Hotels Should also look in the factors affecting less preferance in some particular room type. So,overall if other room types will also gain popularity then again hotel will be benefitted. So, ultimately, Hotels will encounters more bookings resulting in much more revenues.
#
# Ofcourse the bettter understanding regarding the different types of guests will help to take proper right steps towards services, facilities requirements and offers which will directly result in the growth in business.

# %% [markdown]
# ## **Chart12- Correlation Heatmap**

# %%
#correlation heatmap visualization code
plt.figure(figsize=(18,10))
sns.heatmap(hotel_df1.corr(),annot=True)
plt.title('co-relation of columns',fontsize=15)
# Out:
# <ipython-input-60-f9b5c1d886a2>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(hotel_df1.corr(),annot=True)
# Text(0.5, 1.0, 'co-relation of columns')

# %% [markdown]
# **1.** **Why did you pick the specific chart?**
#
# A correlation matrix is a table showing correlation coefficients between bles. Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses. The range of correlation is [-1,1].
#
# Thus to know the correlation between all the variables along with the correlation coeficients, we have used correlation heatmap.
#
# **2.** **What is/are the insight(s) found from the chart?**
#
# 1. is_canceled and total_stay are negatively corelated. This means customers are umlikely to cancel their bookings if they dont't get the same room as per reserved room. We have visualized it above.
#
# 2. lead_time and total_stay is positively corelated. This means more the stay of customer is, more will be the lead time.
#
# 3. adults childrens and babies are corelated to each other. This indicates more the people, more will be adr.
#
# 4. is_repeated guest and previous bookings not canceled have a strong corelation. This may be due to the reason that repeated guests are not more interested to cancel their bookings.
#
# 5. So these are some powerful insights found from the chart of corelation heatmap.

# %% [markdown]
# # **Solution to Business Objective**
#
# **What do you suggest the client to achieve Business Objective?**
#
# Explain Briefly
#
#
# **Business objective attained as follows:**
#
# 1. To attain high growth and more success, hotel business need to flourish and for that few things which we need to consider is high revenue generation, customers satisfaction and employee retention.
#
# 2. We are able to achieve the same by showing the client which are the months which are high in revenue generation by using various charts and graphs distribution
#
# 3. Enhancing the revenue adopted distribution of which type room are most preffered and reserved and which are the months suitable for visitors
#
# 4. we also have founded the arouses preferences in different categories like most liked meal type optimal stay length, facilities required by customers like cae parking spaces etc. So, all these insights ultimately add to have a better planning for growth and higher revenue.
#
# 5. So,preaparing well by using and understanding these useful outcomes, the client can be well prepared in advance so that minimum grievances would be faced by clients in long run and would help in further enhancement of their hospitality and service
#
# 6. Ask for feedback often from the guests visiting the hotels so that the quality can be upgraded to the next level to increase more guests
#
# 7. Periodically throw Offers to attract the old customers so as to increase the no of repeated guests.

# %% [markdown]
# # **Conclusion**
#
# 1.City Hotel seems to be more preferred among travellers and it also generates more revenue & profit.
#
# 2.Most number of bookings are made in July and August as compared rest of the months.
#
# 3.Room Type A is the most preferred room type among travellers.
#
# 4.Most of the guest stays for 1-4 days in the hotels.
#
# 5.City Hotel retains more number of guests.
#
# 6.Around one-fourth of the total bookings gets cancelled. More cancellations are from City Hotel
#
# 7.New guest tends to cancel bookings more than repeated customers.
#
# 8.Lead time, number of days in waiting list or assignation of reserved room to customer does not affect cancellation of bookings
#
# 9.Corporate has the most percentage of repeated guests while TA/TO has the least whereas in the case of cancelled bookings TA/TO has the most percentage while Corporate has the least.
#
# 10.The length of the stay decreases as ADR increases probably to reduce the cost
